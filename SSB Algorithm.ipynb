# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('SSB Data1.csv')

# %%
df.head(50)
# Out:
#     Sr. No  length(m)  Point_load (kN)  Point_Load eccentric  \
# 0        1        1.0               10                   0.0
# 1        2        1.5               20                   0.0
# 2        3        2.0               30                   0.0
# 3        4        2.5               40                   0.0
# 4        5        3.0               50                   0.0
# 5        6        3.5               60                   0.0
# 6        7        4.0               70                   0.0
# 7        8        4.5               80                   0.0
# 8        9        5.0               90                   0.0
# 9       10        5.5              100                   0.0
# 10      11        6.0              110                   0.0
# 11      12        6.5              120                   0.0
# 12      13        7.0              130                   0.0
# 13      14        7.5              140                   0.0
# ...

# %%
df = df.drop(['Sr. No'], axis =1)

# %%
df.describe()
# Out:
#         length(m)  Point_load (kN)  Point_Load eccentric  a (Eccentricity)  \
# count  130.000000       130.000000            130.000000        130.000000
# mean     5.292308        68.815385             34.753077          1.018615
# std      2.702127        57.706661             42.909826          1.008837
# min      1.000000         0.000000            -96.000000          0.000000
# 25%      3.000000        12.750000              0.000000          0.262500
# 50%      5.000000        60.000000             34.500000          0.665000
# 75%      7.500000       123.750000             71.000000          1.500000
# max     10.000000       187.000000            107.000000          4.500000
#
#                 b  Mmax (at point load)
# count  130.000000            130.000000
# mean     3.755154            153.464000
# std      2.603506            163.779885
# min      0.000000              0.360000
# 25%      1.631250             27.205000
# 50%      3.600000             90.615000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   length(m)             130 non-null    float64
#  1   Point_load (kN)       130 non-null    int64
#  2   Point_Load eccentric  130 non-null    float64
#  3   a (Eccentricity)      130 non-null    float64
#  4   b                     130 non-null    float64
#  5   Mmax (at point load)  130 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 6.2 KB

# %%
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
plt.figure(dpi = 200)
sns.pairplot(df, hue='Mmax (at point load)')
plt.show()
# Out:
# C:\Users\Harshit Panchal\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Harshit Panchal\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Harshit Panchal\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Harshit Panchal\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Harshit Panchal\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
X =  df.drop(['Mmax (at point load)'], axis = 1)

# %%
y = df[['Mmax (at point load)']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#      length(m)  Point_load (kN)  Point_Load eccentric  a (Eccentricity)      b
# 30         1.0                0                   5.0             0.300  0.700
# 62         4.0               60                  42.6             1.800  2.200
# 124        8.0              148                 -84.0             0.400  7.600
# 9          5.5              100                   0.0             0.000  0.000
# 33         4.0                0                  45.0             1.200  2.800
# ..         ...              ...                   ...               ...    ...
# 71         3.5               46                  38.0             1.225  2.275
# 106       10.0              136                 107.0             1.500  8.500
# 14         8.0              150                   0.0             0.000  0.000
# 92         3.0               45                  21.0             0.450  2.550
# 102        8.0              149                  82.0             1.200  6.800
#
# [87 rows x 5 columns]

# %%
X_test
# Out:
#      length(m)  Point_load (kN)  Point_Load eccentric  a (Eccentricity)      b
# 55         8.5                0                  87.0             0.850  7.650
# 40         1.0                0                   4.0             0.100  0.900
# 19         3.0               51                   0.0             1.200  1.800
# 31         2.0                0                  25.0             0.600  1.400
# 115        9.0              155                  97.5             0.450  8.550
# 56         9.0                0                  93.0             0.900  8.100
# 69         1.5               17                   3.0             0.525  0.975
# 105        9.5              124                  93.0             1.430  8.080
# 81         4.0               63                  41.0             1.000  3.000
# 26         6.5              121                   0.0             2.600  3.900
# 95         4.5               73                  43.0             0.680  3.830
# ...

# %%
y_train
# Out:
#      Mmax (at point load)
# 30                   1.05
# 62                 102.17
# 124                264.08
# 9                  137.50
# 33                  37.80
# ..                    ...
# 71                  70.51
# 106                476.43
# 14                 300.00
# 92                  41.78
# 102                381.64
#
# [87 rows x 1 columns]

# %%
y_test
# Out:
#      Mmax (at point load)
# 55                  66.56
# 40                   0.36
# 19                  36.72
# 31                  10.50
# 115                390.43
# 56                  75.33
# 69                   7.40
# 105                407.15
# 81                  93.75
# 26                 188.76
# 95                 106.80
# 27                 220.08
# 64                 245.86
# 4                   37.50
# 97                 165.74
# 100                296.12
# 36                 110.25
# 80                  36.56
# 93                  58.48
# 84                 332.94
# 18                  24.60
# 10                 165.00
# 120                 59.26
# 11                 195.00
# 126                400.00
# 45                  10.71
# 70                  31.03
# 78                   6.69
# 47                  19.44
# 0                    2.50
# 12                 227.50
# 42                   1.98
# 51                  39.20
# 24                 120.12
# ...

# %% [markdown]
# #### Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(X_test)

# %%
prediction
# Out:
# array([[ 95.87605164],
#        [-76.65894577],
#        [ 72.09371863],
#        [-34.38274457],
#        [394.88589726],
#        [107.74577467],
#        [-27.04721572],
#        [365.82232509],
#        [133.02859517],
#        [286.07086181],
#        [150.28906139],
#        [316.63902512],
#        [288.28039621],
#        [ 34.4564945 ],
#        [212.92818016],
#        [326.26053753],
#        [105.07029338],
#        [ 41.31349841],
#        [ 82.69887948],
#        [353.95155379],
#        [ 41.52555532],
#        [182.14102594],
#        [ 51.19774701],
#        [206.75511452],
#        [340.55239079],
#        [-17.31033062],
#        [ 40.19208088],
#        [-24.99430201],
#        [  8.00364346],
#        [-63.9998598 ],
#        [231.36920309],
#        [-56.85581975],
#        [ 51.54621555],
#        [205.80677802],
#        [553.72501029],
#        [299.07392187],
#        [-18.16229005],
#        [-61.65558891],
#        [515.51527717],
#        [144.6704514 ],
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_squared_error(y_test,prediction)
MSE = mean_squared_error(y_test,prediction)
RMSE = np.sqrt(MSE)

# %%
MAE
# Out:
# 2356.4488813110447

# %%
MSE
# Out:
# 2356.4488813110447

# %%
RMSE
# Out:
# 48.543268135870754

# %%
model.predict([[8.50,0,87.0,0.850,7.650]])
# Out:
# array([[95.87605164]])

# %%
model.predict([[8.0, 0, 96, 0.8, 7.2]])
# Out:
# array([[95.81528871]])

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_convert = PolynomialFeatures(degree = 2, include_bias=False)

# %%
model_1 = LinearRegression(fit_intercept=True)

# %%
model_1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
t_predict = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_test,t_predict)
MSE = mean_squared_error(y_test,t_predict)
RMSE = np.sqrt(MSE)

# %%
MAE
# Out:
# 39.37669300386199

# %%
MSE
# Out:
# 2356.4488813110447

# %%
RMSE
# Out:
# 48.543268135870754

# %% [markdown]
# ### Choosing a model

# %%
train_rmse_error = []
test_rmse_error = []

for d in range(1,10):
    
    poly_convert = PolynomialFeatures(degree = d, include_bias= False)
    poly_feat = poly_convert.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(poly_feat, y, test_size=0.3, random_state=101)
    
    model = LinearRegression(fit_intercept=True)
    model.fit(X_train, y_train)
    
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)
    
    train_RMSE = np.sqrt(mean_squared_error(y_train, train_pred))
    test_RMSE = np.sqrt(mean_squared_error(y_test, test_pred))
    
    train_rmse_error.append(train_RMSE)
    test_rmse_error.append(test_RMSE)

# %%
plt.plot(range(1,6),train_rmse_error[:5],label='TRAIN')
plt.plot(range(1,6),test_rmse_error[:5],label='TEST')
plt.xlabel("Polynomial Complexity")
plt.ylabel("RMSE")
plt.legend()
plt.show()

# %%
plt.plot(range(1,10),train_rmse_error,label='TRAIN')
plt.plot(range(1,10),test_rmse_error,label='TEST')
plt.xlabel("Polynomial Complexity")
plt.ylabel("RMSE")
plt.legend()
plt.show()

# %%
plt.plot(range(1,10),train_rmse_error,label='TRAIN')
plt.plot(range(1,10),test_rmse_error,label='TEST')
plt.xlabel("Polynomial Complexity")
plt.ylabel("RMSE")
plt.ylim(0,1000)
plt.legend()
plt.show()

# %%
final_poly = PolynomialFeatures(degree=2,include_bias=False)

# %%
final_model = LinearRegression()

# %%
final_model.fit(final_poly.fit_transform(X),y)
# Out:
# LinearRegression()

# %% [markdown]
# #### Saving Model

# %%
from joblib import dump, load

# %%
dump(final_model, 'ssb_poly_model.joblib')
# Out:
# ['ssb_poly_model.joblib']

# %%
dump(final_poly,'poly_converter.joblib')
# Out:
# ['poly_converter.joblib']

# %% [markdown]
# #### Deployement And Prediction

# %%
loaded_poly = load('poly_converter.joblib')
loaded_model = load('ssb_poly_model.joblib')

# %%
campaign = [[8,0,96,0.8,7.2]]

# %%
campaign_poly = loaded_poly.transform(campaign)

# %%
campaign_poly
# Out:
# array([[8.000e+00, 0.000e+00, 9.600e+01, 8.000e-01, 7.200e+00, 6.400e+01,
#         0.000e+00, 7.680e+02, 6.400e+00, 5.760e+01, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 9.216e+03, 7.680e+01, 6.912e+02, 6.400e-01,
#         5.760e+00, 5.184e+01]])

# %%
final_model.predict(campaign_poly)
# Out:
# array([[67.68803494]])
